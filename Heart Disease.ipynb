# %%
#Statistical Visualization and Machine Learning Analysis applied to a Heart Disease DataSet.
#Author: Fábio de Andrade Chacon

# %%
# %matplotlib inline 
import numpy as np #linear algebra
import matplotlib.pyplot as plt
import seaborn as sns #data visialization
import pandas as pd   #data manipulation and visualization
import colorsys
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, validation_curve, learning_curve
from sklearn.externals import joblib

# %% [markdown]
# Columns
# age age in years
# sex(1 = male; 0 = female)
# cpchest pain type
# trestbps resting blood pressure (in mm Hg on admission to the hospital)
# chol serum cholestoral in mg/dl
# fbs (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg resting electrocardiographic results
# thalach maximum heart rate achieved
# exang exercise induced angina (1 = yes; 0 = no)
# oldpeakST depression induced by exercise relative to rest
# slopethe slope of the peak exercise ST segment
# canumber of major vessels (0-3) colored by flourosopy
# thal3 = normal; 6 = fixed defect; 7 = reversable defect
# target1 or 0

# %%
df = pd.read_csv(r"C:\Users\fabio\Documents\DataSets\csv_data\heart.csv")

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['age'].std()
# Out:
# 9.082100989837858

# %%
#data = df.drop('target', axis=1).drop(axis=1, index=0)

# %%
validate = df.iloc[0:1, :-1] #Removes one example.

# %%
#Separates the examples from the ground truth labels.
data, data_labels = df.iloc[1:, :-1].values, df.iloc[1:, -1:].values

# %%
#Split the data into a training set and a test set (30% of the data is destined to test the performance of the model).
x_train, x_test, y_train, y_test = train_test_split(data, data_labels, test_size=0.30, stratify=data_labels)

# %% [markdown]
# The next cells compare the performance of three classifiers.

# %%
#Standardizes the data for optimal gradient-based optimization.
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
#Plots a validation curve.
def val_curve(est, x, y, par_name):
    param_range=[0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
    train_scores, test_scores = validation_curve(estimator=est,
                                                 X=x,
                                                 y=y.ravel(),
                                                 param_name=par_name,
                                                 param_range=param_range,
                                                 cv=10)
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    plt.plot(param_range, train_mean, color='blue', marker='o', markersize=5, label='training accuracy')
    plt.fill_between(param_range, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
    plt.plot(param_range, test_mean, color='red', marker='s', linestyle='--', markersize=5, label='test accuracy')
    plt.fill_between(param_range, test_mean + test_std, test_mean - test_std, alpha=0.15)
    
    plt.grid()
    plt.xscale('log')
    plt.xlabel('Parameter C')
    plt.ylabel('Accuracy')
    plt.ylim([0.8, 1.03])
    plt.show()

# %%
#Fits the model with Logistic Regression.
lr = LogisticRegression(C=100, random_state=0)
lr.fit(x_train_std, y_train.ravel())
y_pred = lr.predict(x_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test.ravel(), y_pred))
# Out:
# Accuracy: 0.87

# %%
joblib.dump(lr, 'logregressionmodel.pkl')
# Out:
# ['logregressionmodel.pkl']

# %%
pipe_lr = make_pipeline(StandardScaler(), lr)

# %%
#The information provided by this curve is used as feedback for hyperparameter tuning and model selection.
val_curve(est=pipe_lr, x=x_train, y=y_train, par_name='logisticregression__C')

# %%
lr.predict(x_test[0:3, :])
# Out:
# array([0, 0, 0], dtype=int64)

# %%
target = lr.predict(validate)
print("Logistic Regression prediction: ", str(target))
# Out:
# Logistic Regression prediction:  [0]

# %%
#Fiting the model using Naive Bayes.
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train_std, y_train.ravel())
y_pred = model.predict(x_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.84

# %%
target = model.predict(validate)
print("Naive Bayes prediction: ", str(target))
# Out:
# Naive Bayes prediction:  [0]

# %%
#Fits an SVM model with a nonlinear Kernel.
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, C=3.0)
svm.fit(x_train_std, y_train.ravel())
y_pred = svm.predict(x_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.84

# %%
target = svm.predict(validate)
print("SVM prediction: ", str(target))
# Out:
# SVM prediction:  [0]

# %%
#Reduces the Dimension via PCA.
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
x_train_pca = pca.fit_transform(x_train_std)
x_test_pca = pca.transform(x_test_std)
lr.fit(x_train_pca, y_train.ravel())
y_pred_pca = lr.predict(x_test_pca)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_pca))
# Out:
# Accuracy: 0.87

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize': (10, 6)})

# %%
df.age.hist(bins=60)
plt.xlabel('Idade')
plt.ylabel('Pacientes diagnosticados')
plt.title('Heart Disease')
plt.show()

# %%
ax = df.groupby(['age'])['target'].aggregate(sum).reset_index().sort_values(['target'], ascending=True)
ax = ax.tail(15).plot(kind='barh', x='age', y='target')
ax.set_title("Quantidade de pacientes diagnosticados", fontsize=14)
# Out:
# Text(0.5,1,'Quantidade de pacientes diagnosticados')

# %%
from numpy import median
sns.catplot(x='sex', y='target', col='age', hue='sex', estimator=median, data=df, height=3, col_wrap=3, kind='bar')
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
labels = df.sex.value_counts().index
num = len(df.target.value_counts().index)

HSV = [(x*1.0/num, 0.5, 0.5) for x in range(num)]
RGB = list(map(lambda x: colorsys.hsv_to_rgb(*x), HSV))

fatias, texto = plt.pie(df.target.value_counts(), colors = RGB, 
                        startangle = 90)
plt.axes().set_aspect('equal', 'datalim')
plt.legend(fatias, labels, bbox_to_anchor = (1.05,1))
plt.title("")
plt.show()
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
labels = df.sex.value_counts().index
num = len(df.target.value_counts().index)

HSV = [(x*1.0/num, 0.5, 0.5) for x in range(num)]
RGB = list(map(lambda x: colorsys.hsv_to_rgb(*x), HSV))
colors = ['OliveDrab', 'Orange', 'OrangeRed', 'DarkCyan', 'Salmon', 
          'Sienna', 'Maroon', 'LightSlateGrey', 'DimGray']

fatias, texto = plt.pie(df.sex.value_counts(), colors = RGB, 
                        startangle = 90)
plt.axes().set_aspect('equal', 'datalim')
plt.legend(fatias, labels, bbox_to_anchor = (1.05,1))
plt.title("")
plt.show()
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
sns.distplot(df.age, kde=False, rug=True)
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
col_rename = {'trestbps' : 'resting blood pressure'}
df.rename(columns=col_rename)
sns.jointplot(x='age', y='resting blood pressure', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-696e9c2a057c> in <module>()
#       1 col_rename = {'trestbps' : 'resting blood pressure'}
#       2 df.rename(columns=col_rename)
# ----> 3 sns.jointplot(x='age', y='resting blood pressure', data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2282     grid = JointGrid(x, y, data, dropna=dropna,
#    2283                      height=height, ratio=ratio, space=space,
# -> 2284                      xlim=xlim, ylim=ylim)
#    2285
#    2286     # Plot the data using the grid
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size)
#    1707             if isinstance(var, string_types):
#    1708                 err = "Could not interpret input '{}'".format(var)
# -> 1709                 raise ValueError(err)
#    1710
#    1711         # Find the names of the variables
#
# ValueError: Could not interpret input 'resting blood pressure'

# %%
sns.pairplot(data=df)
