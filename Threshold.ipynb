# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = r'C:\Users\fabio\Documents\foto2.jpg'

# %%
img = cv2.imread(img_path)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1587.5, 1624.5, -0.5)

# %%
img[img>160]=255
img[img<160]=0.0
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1587.5, 1624.5, -0.5)
